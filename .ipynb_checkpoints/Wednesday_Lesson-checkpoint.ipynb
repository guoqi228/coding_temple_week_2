# %% [markdown]
# # Data Collections 2 (Dictionaries, Sets) and Importing Modules

# %% [markdown]
# ## Tasks Today:
#
# 1) Dictionary <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Declaring (key, value) <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Accessing Values <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; ------ Exercise #1 - Print the eye color of each person in a double nested dict <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Adding New Pairs <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Modifying Values <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Removing Key, Value Pairs <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) Looping a Dictionary <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) Looping Only Keys <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; h) Looping Only Values <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; ------ Exercise #2 - Create a Function that Prints All Key Value Pairs within a print .format()  <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; i) sorted() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; j) Lists with Dictionaries <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; k) Dictionaries with Lists <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; l) Dictionaries with Dictionaries <br>
# 2) Hashing & Big 'O' Notation <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; ------ Exercise #3 - Write a Function that asks someone's name and address, and then stores that into a dictionary, which prints all names and addresses after they're done putting information in...  <br>
# 3) Set <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Declaring <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) .add() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) .union() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) .intersection() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) .difference() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) Frozen Set <br>
# 4) Modules <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Importing Entire Modules <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Importing Methods Only <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Using the 'as' Keyword <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Creating a Module <br>
# 5) Exercises <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Build a Shopping Cart <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Create Your Own Module <br>

# %% [markdown]
# ## Dictionary <br>
# <p>A collection of data with 'key:value' pairs</p>

# %% [markdown]
# ##### Declaring (key, value)

# %%
# keys should be unique
# can use numbers or strings
my_dict = {'key': 'value',
          'key2': 'value',
          'key3': 4}
my_dict
# Out:
# {'key': 'value', 'key2': 'value', 'key3': 4}

# %% [markdown]
# ##### Accessing Values

# %%
# dict[key]
my_dict['key']
num_dict = {
    6: 'd',
    7: 'e',
    4: 'g',
    0: 'a',
    1: 'b',
    2: 'c'
}
sorted(num_dict.values())
# Out:
# ['a', 'b', 'c', 'd', 'e', 'g']

# %% [markdown]
# ## Exercise #1 - Print the eye color of each person in a double nested dict

# %%
# use the list below

people = {
    'Connor' : {
        'eyes' : 'blue'
    },
    'Max' : {
        'eyes' : 'brown'
    },
    'Evan' : {
        'eyes' : 'black'
    },
    'Tristan' : {
        'eyes' : 'brown'
    }
}

people['Max']['eyes']
people['Max']
# Out:
# {'eyes': 'brown'}

# %% [markdown]
# ##### Adding New Pairs

# %%
# dict[key] = value
my_dict['Matt'] = 'House'
my_dict
# Out:
# {'key': 'value', 'key2': 'value', 'key3': 4, 'Matt': 'House'}

# %% [markdown]
# ##### Modifying Values

# %%
# dict[key] = value
del my_dict['key']
my_dict
# Out:
# {'key2': 'value', 'key3': 4, 'Matt': 'House'}

# %% [markdown]
# ##### Removing Key, Value Pairs

# %%
# del dict[key]
my_dict.items()
# Out:
# dict_items([('key2', 'value'), ('key3', 4), ('Matt', 'House')])

# %% [markdown]
# ##### Looping a Dictionary

# %%
# .items()
for key, value in my_dict.items():
    print('{} likes to eat at {}!'.format(key, value))
# Out:
# key2 likes to eat at value!
# key3 likes to eat at 4!
# Matt likes to eat at House!

# %% [markdown]
# ##### Looping Only Keys

# %%
# .keys()
num_dict.keys()
# Out:
# dict_keys([6, 7, 4, 0, 1, 2])

# %% [markdown]
# ##### Looping Only Values

# %%
# .values()
list(zip(num_dict.keys(),num_dict.values()))
# Out:
# [(6, 'd'), (7, 'e'), (4, 'g'), (0, 'a'), (1, 'b'), (2, 'c')]

# %%
num_dict
# Out:
# {6: 'd', 7: 'e', 4: 'g', 0: 'a', 1: 'b', 2: 'c'}

# %% [markdown]
# ## Exercise #2 - Create a Function that Prints All Key Value Pairs within a print .format()

# %%
people = {
    'Connor' : {
        'eyes' : 'blue'
    },
    'Max' : {
        'eyes' : 'brown'
    },
    'Evan' : {
        'eyes' : 'black'
    },
    'Tristan' : {
        'eyes' : 'brown'
    }
}

def eye_color(a_dict):
    for k, v in a_dict.items():
        print('{} has {} eyes.'.format(k, v['eyes']))
        
eye_color(people)
# Out:
# Connor has blue eyes.
# Max has brown eyes.
# Evan has black eyes.
# Tristan has brown eyes.

# %%
dict_1 = {1:'a', 2:'b', 3:'c'}
dict_2 = {4:'f', 5:'g', 6:'h'}

(dict_1, dict_2)

def merge_dicts(d1, d2):
    return {k: v for d in (d1, d2) for k, v in d.items()}

d = (dict_1, dict_2)
d[0]
[dict_1]
{k: v for d in (dict_1, dict_2) for k, v in d.items()}
# Out:
# {1: 'a', 2: 'b', 3: 'c', 4: 'f', 5: 'g', 6: 'h'}

# %% [markdown]
# ##### sorted()

# %%
# sorts keys in order and returns keys only

# %% [markdown]
# ##### List with Dictionaries

# %%
my_list = [
    {1:'a'}, {2:'b'}
]

# %% [markdown]
# ##### Dictionaries with Lists

# %% [markdown]
# ##### Dictionaries with Dictionaries

# %% [markdown]
# ## Hashing and Big O Notation

# %%
# hash()
a = hash(2131)
a

b = hash('Hello!')
b
# Out:
# 159938281806303248

# %% [markdown]
# ## Exercise #3 - Write a Function that asks someone's name and address, and then stores that into a dictionary, which prints all names and addresses after they're done putting information in...

# %%
def ask_info():
    all_info = {}
    keep_asking = True
    while keep_asking:
        
        is_string = False
        while not is_string:
            try:
                name = str(input('Enter your name: '))
                if name.isalpha() == False:
                    print('Name can only contain letters! Please re-enter.')
                    continue
                else:
                    is_string = True
            except:
                print('Name can only contain letters! Please re-enter.')
        
        address = input('Please enter your address: ')
        
        all_info[name] = address
        
        is_y_or_n = False
        while not is_y_or_n:
            try:
                y_or_n = str(input('Do you want to enter another name and address? y or n: '))
                if y_or_n == 'n':
                    is_y_or_n = True
                    keep_asking = False
                elif y_or_n == 'y':
                    is_y_or_n = True
                    break
                else:
                    print('Invalid input. Please enter y or n!')
            except:
                print('Invalid input. Please enter y or n!')
    print('\n')    
    print('Exiting...')
    print('Printing all the information:')
    for k, v in all_info.items():
        print('Name: {}, Address: {}'.format(k, v))
        
ask_info()
# Out:
# Enter your name: 21312
# Name can only contain letters! Please re-enter.
# Enter your name: asda asdasd2
# Name can only contain letters! Please re-enter.
# Enter your name: dadd
# Please enter your address: 2da2dad
# Do you want to enter another name and address? y or n: y
# Enter your name: 21312
# Name can only contain letters! Please re-enter.
# Enter your name: asdasd
# Please enter your address: 213sadd as da
# Do you want to enter another name and address? y or n: y
# Enter your name: 21312
# Name can only contain letters! Please re-enter.
# Enter your name: sfsada
# Please enter your address: 23asdad
# Do you want to enter another name and address? y or n: y
# Enter your name: sfsffa
# Please enter your address: 23asddadd
# Do you want to enter another name and address? y or n: n
#
#
# Exiting...
# Printing all the information:
# Name: dadd, Address: 2da2dad
# Name: asdasd, Address: 213sadd as da
# Name: sfsada, Address: 23asdad
# Name: sfsffa, Address: 23asddadd

# %% [markdown]
# ## Set <br>
# <p>A Set is an unordered collection data type that is iterable, mutable, and has no duplicate elements.<br>Major advantage is that it is highly optimized in checking if something is in the set, as opposed to checking if something is in a list.</p>

# %% [markdown]
# ##### Declaring

# %%
# set() or {}
my_set = {2, 3, 4, 5, 4}
my_set
# Out:
# {2, 3, 4, 5}

# %%
my_set = set((2, 3, 4, 5, 4, 6, 7, 3, 2))
my_set
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
s = 'asknafhakfnhasfnaslgsognsdp'
set(s)
# Out:
# {'a', 'd', 'f', 'g', 'h', 'k', 'l', 'n', 'o', 'p', 's'}

# %%
{'asknafhakfnhasfnaslgsognsdp'}
# Out:
# {'asknafhakfnhasfnaslgsognsdp'}

# %% [markdown]
# ##### .add()

# %% [markdown]
# ##### .union()

# %%
# Returns a union of two sets, can also use '|'

my_set1 = {0, 1, 2, 3}
my_set2 = {2, 3, 4, 5}

# %%
s = "The Holy Bible"
s.strip()
# Out:
# 'The Holy Bible'

# %% [markdown]
# ##### .intersection()

# %%
# Returns an intersection of two sets, can also use '&'
out = []
out.append(1)
out
# Out:
# [1]

# %% [markdown]
# ##### .difference()

# %%
# Returns a set containing all the elements of invoking set but not of the second set, can also use '-'

# %% [markdown]
# ##### .clear()

# %%
# Empties the whole set

# %% [markdown]
# ##### Frozenset <br>
# <p>Frozen sets are immutable objects that only support methods and operators that produce a result without affecting the frozen set or sets to which they are applied.</p><br><b>Unique & Immutable</b>

# %%
# frozenset([])

# %% [markdown]
# ## Modules

# %% [markdown]
# ##### Importing Entire Modules

# %%
# import or from 'xxx' import *
import math
from math import *
# floor example

math.floor(6.777)
# Out:
# 6

# %% [markdown]
# ##### Importing Methods Only

# %%
# from 'xxx' import 'xxx'
from math import floor

# %% [markdown]
# ##### Using the 'as' Keyword

# %%
# from 'xxx' import 'xxx' as 'xxx' or import 'xxx' as 'xxx'
from math import floor as f

f(4.56654)
# Out:
# 4

# %% [markdown]
# ##### Creating a Module

# %%
# %run D:\coding_temple_week_2\sample.py

add_sum(18,9)
# Out:
# 27

# %%
12 in range(2,44)
# Out:
# True

# %% [markdown]
# # Exercises

# %% [markdown]
# ### 1) Build a Shopping Cart <br>
# <p><b>Should have the following capabilities:</b><br><br>
# 1) Takes in input <br>
# 2) Stores user input into a dictionary <br>
# 3) User can add or delete items <br>
# 4) User can see current shopping list <br>
# 5) Loops until user 'quits' <br>
# 6) Upon quiting the program, print out all items in the user's list <br>
# </p>

# %%
########################################
########################################
def show_menu():
    '''
    show menu
    '''
    print('\n')
    print('Menu')
    print('========================================')
    print('0 -> Show all items')
    print('1 -> Add item')
    print('2 -> Remove item')
    print('3 -> Show item in shopping cart')
    print('4 -> Check out')
    print('5 -> Cancel')
    print('========================================')
########################################
########################################
def show_all_items(all_items):
    '''
    show all items 
    '''
    print('\n')
    print('All items:')
    print('========================================')
    for i, item in enumerate(all_items):
        print('{}. {} ------${}'.format(i, item[0], item[1]))
    print('========================================')
########################################
########################################
def show_cart(cart):
    '''
    show all items in shopping cart
    '''
    print('\n')
    print('Items in shopping cart:')
    print('========================================')
    for i, item in enumerate(cart):
        print('{}. {} ------${}'.format(i, item[0], item[1]))
    print('========================================')   
########################################
########################################
def add_to_cart(cart, all_items):
    '''
    name: item name to be added
    price: item price
    cart: a list storing (name, price) tuples
    '''
    n = len(all_items)
    show_all_items(all_items)
    valid_num = False
    while not valid_num:
        try:
            item_num = int(input('Enter the item you want to add: '))
            if item_num not in range(n):
                print('Invalid input. Please enter the item number!')
                continue
            else:
                valid_num = True
                cart.append(all_items[item_num])
                print('Item {} added.'.format(item_num))
        except:
            print('Invalid input. Please enter the item number!')    
########################################
########################################
def remove_from_cart(cart):
    '''
    cart: a list as shopping cart is input
    '''
    if len(cart) == 0:
        print('Your shopping cart is empty!')
        return False
    n = len(cart)
    show_cart(cart)
    valid_num = False
    while not valid_num:
        try:
            item_num = int(input('Enter the item you want to remove: '))
            if item_num not in range(n):
                print('Invalid input. Please enter the item number!')
                continue
            else:
                valid_num = True
                del cart[item_num]
                print('Item {} removed.'.format(item_num))
        except:
            print('Invalid input. Please enter the item number!')
########################################
########################################
def check_out(cart):
    '''
    check out current cart: return the total price in cart
    '''
    if len(cart) == 0:
        print('Your cart is empty!')
        return True
    print('Items in your shopping cart: ')
    show_cart(cart)
    print('Checking out...')
    print('========================================')
    total_price = 0
    for item in cart:
        total_price += item[1]
    print('Your total is: ${}'.format(total_price))
    print('Thanks for shopping with us.')
    
    is_y_or_n = False
    while not is_y_or_n:
        try:
            y_or_n = str(input('Do you want to continue shopping? y or n: '))
            if y_or_n == 'n':
                is_y_or_n = True
                return False
            elif y_or_n == 'y':
                is_y_or_n = True
                return True
            else:
                print('Invalid input. Please enter y or n!')
        except:
            print('Invalid input. Please enter y or n!')
    #print('See you next time')
    #keep_shopping = False
########################################
########################################
def cancel():
    print('Transation cancelled!')
    is_y_or_n = False
    while not is_y_or_n:
        try:
            y_or_n = str(input('Do you want to continue shopping? y or n: '))
            if y_or_n == 'n':
                is_y_or_n = True
                return False
            elif y_or_n == 'y':
                is_y_or_n = True
                return True
            else:
                print('Invalid input. Please enter y or n!')
        except:
            print('Invalid input. Please enter y or n!')
    #keep_shopping = False

########################################
########################################
from IPython.display import clear_output

def start_shopping():
    
    all_items = (('Chip', 3.98), 
            ('Beer', 6.99), 
            ('Soda', 5.98), 
            ('Chicken wing',11.99), 
            ('Beef',15.99), 
            ('Chocolate',5.02), 
            ('Juice',6.98),
            ('Wine',15.98))
        
    shopping_cart = []
    keep_shopping = True
    user_option = None
    
    while keep_shopping:
        
        show_menu()
        
        valid_option = False
        while not valid_option:
            try:
                user_option = int(input('Choose a option from menu: '))
                if user_option not in range(6):
                    print('Please enter a valid option!')
                    continue
                else:
                    valid_option = True
                        
            except:
                print('Please enter a valid option!')
            
        if user_option == 0:
            clear_output()
            show_all_items(all_items)
        elif user_option == 1:
            clear_output()
            add_to_cart(shopping_cart, all_items)
        elif user_option == 2:
            clear_output()
            remove_from_cart(shopping_cart)
        elif user_option == 3:
            clear_output()
            show_cart(shopping_cart)
        elif user_option == 4:
            clear_output()
            keep_shopping = check_out(shopping_cart)
            shopping_cart = []
        elif user_option == 5:
            clear_output()
            keep_shopping = cancel()
            shopping_cart = []
        else:
            clear_output()
            continue
    print('See you next time!')

start_shopping()
# Out:
# Transation cancelled!
# Do you want to continue shopping? y or n: n
# See you next time!

# %%
all_item = {'Chip': 3.98,
                'Beer': 6.99,
                'Soda': 5.98,
                'Chicken wing':11.99,
                'Beef': 15.99,
                'Chocolate':5.02,
                'Juice': 6.98,
                'Wine': 15.98}

    
show_menu()


cart_item_name = []
cart_item_price = []
show_all_items(all_item)

# %% [markdown]
# ### 2) Create a Module in Atom and Import It <br>
# <p><b>Module should have the following capabilities:</b><br><br>
# 1) Has a function to calculate the square footage of a house <br>
# 2) Has a function to calculate the circumference of a circle <br><br>
# <b>Program in Jupyter Notebook should take in user input and use imported functions to calculate a circle's circumference or a houses square footage</b>
# </p>
